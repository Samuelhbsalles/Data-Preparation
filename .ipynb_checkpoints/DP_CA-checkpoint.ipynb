# %% [markdown]
# ![cover-page.png](attachment:cover-page.png)

# %% [markdown]
# # Data Preparation Project.
#
#     We were tasked with the followed Scenario:
#
#     Scenario:
#
#     You have been retained by a haulage company to analyse a dataset based on data collected from heavy Scania trucks in everyday usage. The system in focus is the Air Pressure system (APS) which generates pressurised air that are utilized in various functions in a truck, such as braking and gear changes. The dataset’s  positive class consists of component failures for a specific component of the APS system.  The negative class consists of trucks with failures for components not related to the APS. The data consists  of a subset of all available data, selected by experts. This analysis will help determine the investment strategy for the company in the upcoming year.
#
#
#         When you read the scenario you realize that your target variable is the feature which gives you positive and negative.
#     Starting the process to clean the data, create features, normalize the data and so on...

# %% [markdown]
# # Explain in your own words what the “Curse of Dimensionality ” is and how it may affect your analysis going forward.
#
#     Curse of dimensionality in my point of view is add more features or dimensions to my data, the affects that I might have are overfiting the data and also I could have a problem to interpret the data due to huge amount of data.

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; 
import warnings 
warnings.filterwarnings('ignore') 
sns.set()

# %%
aps_failure = pd.read_csv("aps_failure_set.csv")
aps_failure.head()
# Out:
#   class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0   neg   76698     na  2130706438    280      0      0      0      0      0
# 1   neg   33058     na           0     na      0      0      0      0      0
# 2   neg   41040     na         228    100      0      0      0      0      0
# 3   neg      12      0          70     66      0     10      0      0      0
# 4   neg   60874     na        1368    458      0      0      0      0      0
#
#    ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...  1240520  493384  721044  469792  339156  157956   73224      0      0
# 1  ...   421400  178064  293306  245416  133654   81140   97576   1500      0
# 2  ...   277378  159812  423992  409564  320746  158022   95128    514      0
# 3  ...      240      46      58      44      10       0       0      0      4
# 4  ...   622012  229790  405298  347188  286954  311560  433954   1218      0
#
#   eg_000
# 0      0
# 1      0
# ...

# %% [markdown]
# ### STEP 1
# Using .head to see the first five observations we realized that there are missing values.
# However, these missing values are not NaN or empty, it is fill with na, we need to change it, instance to be able to continue our process.

# %%
aps_failure.shape
# Out:
# (60000, 171)

# %% [markdown]
# To be able to see how much data we are working with, I used .shape and as we can see it there are 60.000 observations and 171 features.

# %%
aps_failure.describe()
# Out:
#              aa_000
# count  6.000000e+04
# mean   5.933650e+04
# std    1.454301e+05
# min    0.000000e+00
# 25%    8.340000e+02
# 50%    3.077600e+04
# 75%    4.866800e+04
# max    2.746564e+06

# %%
aps_failure.dtypes
# Out:
# class     object
# aa_000     int64
# ab_000    object
# ac_000    object
# ad_000    object
#            ...
# ee_007    object
# ee_008    object
# ee_009    object
# ef_000    object
# eg_000    object
# Length: 171, dtype: object

# %%
aps_failure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 171 entries, class to eg_000
# dtypes: int64(1), object(170)
# memory usage: 78.3+ MB

# %% [markdown]
# # Cleaning the data
#
#     To be able to continue all the process I need to change 'na' to NaN.

# %%
aps_failure.head()
# Out:
#   class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0   neg   76698     na  2130706438    280      0      0      0      0      0
# 1   neg   33058     na           0     na      0      0      0      0      0
# 2   neg   41040     na         228    100      0      0      0      0      0
# 3   neg      12      0          70     66      0     10      0      0      0
# 4   neg   60874     na        1368    458      0      0      0      0      0
#
#    ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...  1240520  493384  721044  469792  339156  157956   73224      0      0
# 1  ...   421400  178064  293306  245416  133654   81140   97576   1500      0
# 2  ...   277378  159812  423992  409564  320746  158022   95128    514      0
# 3  ...      240      46      58      44      10       0       0      0      4
# 4  ...   622012  229790  405298  347188  286954  311560  433954   1218      0
#
#   eg_000
# 0      0
# 1      0
# ...

# %% [markdown]
# # Step 1 - dealing with missing data.
#
#      The code below are replacing 'na' to NaN and then we will be able to see the total of missing data in our dataset and I also plot the missing data to understand better.

# %%
df_aps= aps_failure.replace('na',np.nan)

# %%
df_aps
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0       neg   76698    NaN  2130706438    280      0      0      0      0
# 1       neg   33058    NaN           0    NaN      0      0      0      0
# 2       neg   41040    NaN         228    100      0      0      0      0
# 3       neg      12      0          70     66      0     10      0      0
# 4       neg   60874    NaN        1368    458      0      0      0      0
# ...     ...     ...    ...         ...    ...    ...    ...    ...    ...
# 59995   neg  153002    NaN         664    186      0      0      0      0
# 59996   neg    2286    NaN  2130706538    224      0      0      0      0
# 59997   neg     112      0  2130706432     18      0      0      0      0
# 59998   neg   80292    NaN  2130706432    494      0      0      0      0
# 59999   neg   40222    NaN         698    628      0      0      0      0
#
#       ag_002  ...   ee_002  ee_003   ee_004   ee_005   ee_006  ee_007  ee_008  \
# ...

# %% [markdown]
# I've changed all the columns with values 'na' to 'NaN'.

# %%
df_aps.dtypes
# Out:
# class     object
# aa_000     int64
# ab_000    object
# ac_000    object
# ad_000    object
#            ...
# ee_007    object
# ee_008    object
# ee_009    object
# ef_000    object
# eg_000    object
# Length: 171, dtype: object

# %%
df_aps.isnull().sum()
# Out:
# class         0
# aa_000        0
# ab_000    46329
# ac_000     3335
# ad_000    14861
#           ...
# ee_007      671
# ee_008      671
# ee_009      671
# ef_000     2724
# eg_000     2723
# Length: 171, dtype: int64

# %% [markdown]
# There are too many missing data on the dataset as you can see upon, I am going to plot the missing data to visualize better.

# %%
#!pip install missingno

# %%
import missingno as msno

# %%
ax =msno.matrix(df_aps.sample(600))

# %% [markdown]
#     The white part is where the missing values are.

# %%
msno.heatmap(df_aps, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
df_aps.shape
# Out:
# (60000, 171)

# %%
df_aps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 171 entries, class to eg_000
# dtypes: int64(1), object(170)
# memory usage: 78.3+ MB

# %%
df_aps2 = df_aps.fillna(0)

# %% [markdown]
# # in this process I filled the missing values with 0, because I'll calculate the mean and fill all the 0 that before were NaN to the mean.

# %%
df_aps2.head()
# Out:
#   class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0   neg   76698      0  2130706438    280      0      0      0      0      0
# 1   neg   33058      0           0      0      0      0      0      0      0
# 2   neg   41040      0         228    100      0      0      0      0      0
# 3   neg      12      0          70     66      0     10      0      0      0
# 4   neg   60874      0        1368    458      0      0      0      0      0
#
#    ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...  1240520  493384  721044  469792  339156  157956   73224      0      0
# 1  ...   421400  178064  293306  245416  133654   81140   97576   1500      0
# 2  ...   277378  159812  423992  409564  320746  158022   95128    514      0
# 3  ...      240      46      58      44      10       0       0      0      4
# 4  ...   622012  229790  405298  347188  286954  311560  433954   1218      0
#
#   eg_000
# 0      0
# 1      0
# ...

# %%
mean = df_aps2[df_aps2!= 0].mean()
## I'm ignoring the 0 and calc the mean.

# %%
df_aps3 = df_aps2.replace(0, mean)

# %%
df_aps3.head()
# Out:
#   class   aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0   neg  76698.0      0  2130706438    280      0      0      0      0      0
# 1   neg  33058.0      0           0      0      0      0      0      0      0
# 2   neg  41040.0      0         228    100      0      0      0      0      0
# 3   neg     12.0      0          70     66      0     10      0      0      0
# 4   neg  60874.0      0        1368    458      0      0      0      0      0
#
#    ...   ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000  \
# 0  ...  1240520  493384  721044  469792  339156  157956   73224      0      0
# 1  ...   421400  178064  293306  245416  133654   81140   97576   1500      0
# 2  ...   277378  159812  423992  409564  320746  158022   95128    514      0
# 3  ...      240      46      58      44      10       0       0      0      4
# 4  ...   622012  229790  405298  347188  286954  311560  433954   1218      0
#
#   eg_000
# 0      0
# ...

# %%
df_aps3.isnull().sum()
# Out:
# class     0
# aa_000    0
# ab_000    0
# ac_000    0
# ad_000    0
#          ..
# ee_007    0
# ee_008    0
# ee_009    0
# ef_000    0
# eg_000    0
# Length: 171, dtype: int64

# %% [markdown]
# # Explain the process.
#
#     I've changed na to NaN at the beggining after that I filled the columns NaN with 0, why? Because, I want to calc the mean avoing 0 and so I can change 0 for the mean value.

# %%
df_new = pd.get_dummies(df_aps3, columns=['class'])

# %% [markdown]
#     I used the pd.get_dummies to change the class to 0 and 1, because is a completely different method that I used before.
#     I could have used .replace, however, I tried to use new codes and methods I learnt throughout the course.

# %%
df_new.head()
# Out:
#     aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0  76698.0      0  2130706438    280      0      0      0      0      0
# 1  33058.0      0           0      0      0      0      0      0      0
# 2  41040.0      0         228    100      0      0      0      0      0
# 3     12.0      0          70     66      0     10      0      0      0
# 4  60874.0      0        1368    458      0      0      0      0      0
#
#   ag_003  ...  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009 ef_000 eg_000  \
# 0      0  ...  721044  469792  339156  157956   73224      0      0      0
# 1      0  ...  293306  245416  133654   81140   97576   1500      0      0
# 2      0  ...  423992  409564  320746  158022   95128    514      0      0
# 3    318  ...      58      44      10       0       0      0      4     32
# 4      0  ...  405298  347188  286954  311560  433954   1218      0      0
#
#   class_neg class_pos
# 0         1         0
# 1         1         0
# ...

# %%
df_aps4 = df_new.drop(columns="class_pos")

# %%
df_aps4.class_neg.value_counts(dropna=False)
# Out:
# 1    59000
# 0     1000
# Name: class_neg, dtype: int64

# %% [markdown]
#     Above as you can see it there are in total 59.000 negatives and 1000 positives.

# %%
sns.barplot(data=df_aps4,x=df_aps4['class_neg'].unique(),y=df_aps4['class_neg'].value_counts())
# Out:
# <Axes: ylabel='class_neg'>

# %% [markdown]
# # STEP 2
#     In this process I scaled all the columns.
#     One of the things that I notice was the huge difference between positive and negative and I tried to apply a process call smote we learnt at class with our professor of machine learning.
#     Basically, when we have huge difference this method help us to under-sampling or over-sampling depends what you want to do, in my case, I'll use over-sampling, because, I want to analyze positive and negative without the huge difference.
#     NOTE: If I try to use over-sampling my dataset will be over-fitting.

# %%
aps_scaled = df_aps4.drop(columns='class_neg')
aps_scaled_drop = df_aps4['class_neg']

# %%
import sklearn.preprocessing as preproc
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # StandardScaler

# %%
scaler = preprocessing.StandardScaler()

# %%
scaled_aps = preproc.StandardScaler().fit_transform(df_aps4)

# %%
scaled_aps.shape, aps_scaled_drop.shape
# Out:
# ((60000, 171), (60000,))

# %%
X = scaled_aps
y = aps_scaled_drop

# %%
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import ClusterCentroids 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Under-sampling.
#
#     When I used the code pd.get_dummies(df_aps3, columns=['class']) it created two columns 'class_pos' and 'class_negative', I dropped one of columns to have just one columns with all the values.
#     The reason that I am explaing it, it is because, you are going to see in the Undersampler process 'class_neg', as I said before it because of the process that I did before.

# %%
undersampling = ClusterCentroids()
y_train.value_counts()
# Out:
# 1    39532
# 0      668
# Name: class_neg, dtype: int64

# %%
X_smote, y_smote = undersampling.fit_resample(X, y)

# %%
y_smote.value_counts()
# Out:
# 0    1000
# 1    1000
# Name: class_neg, dtype: int64

# %%
resampled_data = pd.DataFrame({'class_neg': y_smote})

# %%
sns.countplot(data=resampled_data, x='class_neg')
plt.xlabel('class_neg')
plt.ylabel('Count')
plt.title('Distribution of Resampled "class"')
plt.show()

# %% [markdown]
# # Aplying PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA().fit(X_smote) 
plt.plot(np.cumsum(pca.explained_variance_ratio_)) 
plt.xlabel('number of components') 
plt.ylabel('cumulative explained variance');

# %% [markdown]
# # I have ploted the graph that show us to get almost 100% of acurrency we need 100 components.

# %%
pca = PCA(100)
projected = pca.fit_transform(X_smote)

# %%
projected.shape
# Out:
# (2000, 100)

# %%
X_pca = pd.DataFrame(projected)

# %%
X_pca['class_neg'] = resampled_data

# %%
resampled_data.value_counts()
# Out:
# class_neg
# 0            1000
# 1            1000
# dtype: int64

# %%
X_pca.tail()
# Out:
#               0         1         2         3          4         5         6  \
# 1995 -11.825662 -3.124183 -5.447558  4.386578   1.899543 -1.906874  1.290832
# 1996 -24.224976 -0.783780 -1.592510  4.099682   3.262120 -2.856085  0.168032
# 1997   4.862405  0.406135 -3.202178  0.287696 -11.439394  6.821644  4.762710
# 1998  -0.530859 -2.524422 -5.779328  6.105993  -1.416287  0.192813  1.812432
# 1999 -15.600706 -6.241034 -2.199496 -0.476305   3.757809 -2.859489 -6.551521
#
#               7         8         9  ...        91        92        93  \
# 1995  -2.918607  1.226397 -1.552517  ...  0.644044  0.262572 -0.590224
# 1996   0.045854 -0.982466 -1.940603  ...  0.381715 -0.290021 -0.002624
# 1997 -10.711177 -1.257910  7.956875  ... -1.867081 -1.058561 -1.333792
# 1998  -4.196304  4.013004 -1.438744  ...  0.338022  2.230409 -1.163619
# 1999   1.920026 -2.574778  0.477903  ...  0.587305 -0.210997 -0.126402
#
#             94        95        96        97        98        99  class_neg
# ...

# %%
aps_pca = X_pca

# %%
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
X = aps_pca.iloc[:, :1].values # Features
y = aps_pca.iloc[:, -1].values # my target

# %%
print('X shape', X.shape)
print('y shape', y.shape)
# Out:
# X shape (2000, 1)
# y shape (2000,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X.shape, y.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2000, 1), (2000,), (1400, 1), (600, 1), (1400,), (600,))

# %% [markdown]
# # Use of Cross Validation

# %%
# Create an initialise an object 'nvclassifier' by calling a method 'GaussianNB()'
nvclassifier = GaussianNB()

# Calculate the score using cross validation method
cross_val_score(nvclassifier, X, y, scoring = 'accuracy', cv = 40).mean()
# Out:
# 0.9999499999999999

# %% [markdown]
# # Random Forest 52.8%

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf_aps = RandomForestClassifier(n_estimators = 100 )

#Train the model using the training sets y_pred=clf.predict(X_test)
clf_aps.fit(X_train, y_train)

y_pred = clf_aps.predict(X_test)

# %%
from sklearn import metrics

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Rounded upto 2 decimal places
print( "Accuracy: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)) )
# Out:
# Accuracy: 0.5283333333333333
# Accuracy: 0.53

# %% [markdown]
# # Decision Tree 100%
#
#        I've already splitted the data.

# %%
# Create Decision Tree classifer 
clf_aps = DecisionTreeClassifier(criterion = 'entropy',random_state = 0)

# Train Decision Tree Classifer
clf_aps = clf_aps.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf_aps.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Rounded upto 2 decimal places
print( "Accuracy: {:.2f}".format(metrics.accuracy_score(y_test, y_pred)) )
# Out:
# Accuracy: 1.0
# Accuracy: 1.00

# %% [markdown]
# # Conclusions
#         This dataset was huge challenger, since in the process of cleaning the data until validating my model.
#     I tried to use everything I learnt in class and also doing as much research as I could.
#         There is some points I still have a little problem to apply on my model, example of that is:
#     The professor David applied one method to verify all the ML algorith and see which one fits his model, I couldn't apply something like that, because, If I tried would be copying the code.
#     As I am not expert related to trucks and aps systems I couldn't understand what the columns really represents, I knew it that my target would be class due to the scenario and that I should follow all the machine learning process.
#     in my first analyze I dropped all the columns with NaN values, however, my accuracy was 52, so I tried to keep it, and use the mean instead, I succeded to get 100% using Decision Three and 52% using Random Forest.
